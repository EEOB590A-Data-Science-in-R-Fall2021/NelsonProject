# %% [markdown]
# Set up workspace

# %%
import os

# %%
from google.colab import drive #import drive from google colab
ROOT = "/content/drive" # default location for the drive
drive.mount(ROOT)
# Out:
# Mounted at /content/drive

# %%
os.chdir('/content/drive/My Drive/EEOB590A/data')

# %% [markdown]
# R Code

# %%
# !apt-get install r-base
# !pip install -q rpy2
packnames = ("tidyverse", "lme4", "lmerTest", "emmeans", 
             "ggResidpanel", "data.table", "stringr")
from rpy2.robjects.packages import importr
from rpy2.robjects.vectors import StrVector
utils = importr("utils")
utils.chooseCRANmirror(ind=1)
utils.install_packages(StrVector(packnames))
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# r-base is already the newest version (4.1.2-1.1804.0).
# 0 upgraded, 0 newly installed, 0 to remove and 37 not upgraded.
# R[write to console]: Installing packages into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# R[write to console]: also installing the dependencies ‘later’, ‘DEoptimR’, ‘htmlwidgets’, ‘lazyeval’, ‘crosstalk’, ‘promises’, ‘robustbase’, ‘minqa’, ‘nloptr’, ‘RcppEigen’, ‘numDeriv’, ‘estimability’, ‘mvtnorm’, ‘xtable’, ‘cowplot’, ‘plotly’, ‘qqplotr’
#
#
# R[write to console]: trying URL 'https://cloud.r-project.org/src/contrib/later_1.3.0.tar.gz'
#
# R[write to console]: Content type 'application/x-gzip'
# R[write to console]:  length 63785 bytes (62 KB)
#
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]:
#
# R[write to console]: downloaded 62 KB
#
#
# R[write to console]: trying URL 'https://cloud.r-project.org/src/contrib/DEoptimR_1.0-9.tar.gz'
#
# R[write to console]: Content type 'application/x-gzip'
# R[write to console]:  length 36148 bytes (35 KB)
#
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]:
#
# R[write to console]: downloaded 35 KB
#
#
# R[write to console]: trying URL 'https://cloud.r-project.org/src/contrib/htmlwidgets_1.5.4.tar.gz'
#
# R[write to console]: Content type 'application/x-gzip'
# R[write to console]:  length 956850 bytes (934 KB)
#
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]:
#
# R[write to console]: downloaded 934 KB
#
#
# R[write to console]: trying URL 'https://cloud.r-project.org/src/contrib/lazyeval_0.2.2.tar.gz'
#
# R[write to console]: Content type 'application/x-gzip'
# R[write to console]:  length 83482 bytes (81 KB)
#
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]:
#
# R[write to console]: downloaded 81 KB
#
#
# R[write to console]: trying URL 'https://cloud.r-project.org/src/contrib/crosstalk_1.2.0.tar.gz'
#
# R[write to console]: Content type 'application/x-gzip'
# R[write to console]:  length 296495 bytes (289 KB)
#
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]:
#
# R[write to console]: downloaded 289 KB
#
#
# R[write to console]: trying URL 'https://cloud.r-project.org/src/contrib/promises_1.2.0.1.tar.gz'
#
# R[write to console]: Content type 'application/x-gzip'
# R[write to console]:  length 3120504 bytes (3.0 MB)
#
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]:
#
# R[write to console]: downloaded 3.0 MB
#
#
# R[write to console]: trying URL 'https://cloud.r-project.org/src/contrib/robustbase_0.93-9.tar.gz'
#
# R[write to console]: Content type 'application/x-gzip'
# R[write to console]:  length 2344355 bytes (2.2 MB)
#
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]:
#
# R[write to console]: downloaded 2.2 MB
#
#
# R[write to console]: trying URL 'https://cloud.r-project.org/src/contrib/minqa_1.2.4.tar.gz'
#
# R[write to console]: Content type 'application/x-gzip'
# R[write to console]:  length 53548 bytes (52 KB)
#
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]:
#
# R[write to console]: downloaded 52 KB
#
#
# R[write to console]: trying URL 'https://cloud.r-project.org/src/contrib/nloptr_1.2.2.3.tar.gz'
#
# R[write to console]: Content type 'application/x-gzip'
# R[write to console]:  length 2456474 bytes (2.3 MB)
#
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]:
#
# R[write to console]: downloaded 2.3 MB
#
#
# R[write to console]: trying URL 'https://cloud.r-project.org/src/contrib/RcppEigen_0.3.3.9.1.tar.gz'
#
# R[write to console]: Content type 'application/x-gzip'
# R[write to console]:  length 1633360 bytes (1.6 MB)
#
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]:
#
# R[write to console]: downloaded 1.6 MB
#
#
# R[write to console]: trying URL 'https://cloud.r-project.org/src/contrib/numDeriv_2016.8-1.1.tar.gz'
#
# R[write to console]: Content type 'application/x-gzip'
# R[write to console]:  length 76053 bytes (74 KB)
#
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]:
#
# R[write to console]: downloaded 74 KB
#
#
# R[write to console]: trying URL 'https://cloud.r-project.org/src/contrib/estimability_1.3.tar.gz'
#
# R[write to console]: Content type 'application/x-gzip'
# R[write to console]:  length 9481 bytes
#
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]:
#
# R[write to console]: downloaded 9481 bytes
#
#
# R[write to console]: trying URL 'https://cloud.r-project.org/src/contrib/mvtnorm_1.1-3.tar.gz'
#
# R[write to console]: Content type 'application/x-gzip'
# R[write to console]:  length 166421 bytes (162 KB)
#
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]:
#
# R[write to console]: downloaded 162 KB
#
#
# R[write to console]: trying URL 'https://cloud.r-project.org/src/contrib/xtable_1.8-4.tar.gz'
#
# R[write to console]: Content type 'application/x-gzip'
# R[write to console]:  length 564589 bytes (551 KB)
#
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]:
#
# R[write to console]: downloaded 551 KB
#
#
# R[write to console]: trying URL 'https://cloud.r-project.org/src/contrib/cowplot_1.1.1.tar.gz'
#
# R[write to console]: Content type 'application/x-gzip'
# R[write to console]:  length 1353271 bytes (1.3 MB)
#
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]:
#
# R[write to console]: downloaded 1.3 MB
#
#
# R[write to console]: trying URL 'https://cloud.r-project.org/src/contrib/plotly_4.10.0.tar.gz'
#
# R[write to console]: Content type 'application/x-gzip'
# R[write to console]:  length 3842199 bytes (3.7 MB)
#
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]:
#
# R[write to console]: downloaded 3.7 MB
#
#
# R[write to console]: trying URL 'https://cloud.r-project.org/src/contrib/qqplotr_0.0.5.tar.gz'
#
# R[write to console]: Content type 'application/x-gzip'
# R[write to console]:  length 962452 bytes (939 KB)
#
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]:
#
# R[write to console]: downloaded 939 KB
#
#
# R[write to console]: trying URL 'https://cloud.r-project.org/src/contrib/tidyverse_1.3.1.tar.gz'
#
# R[write to console]: Content type 'application/x-gzip'
# R[write to console]:  length 702779 bytes (686 KB)
#
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]:
#
# R[write to console]: downloaded 686 KB
#
#
# R[write to console]: trying URL 'https://cloud.r-project.org/src/contrib/lme4_1.1-27.1.tar.gz'
#
# R[write to console]: Content type 'application/x-gzip'
# R[write to console]:  length 3311365 bytes (3.2 MB)
#
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]:
#
# R[write to console]: downloaded 3.2 MB
#
#
# R[write to console]: trying URL 'https://cloud.r-project.org/src/contrib/lmerTest_3.1-3.tar.gz'
#
# R[write to console]: Content type 'application/x-gzip'
# R[write to console]:  length 195633 bytes (191 KB)
#
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]:
#
# R[write to console]: downloaded 191 KB
#
#
# R[write to console]: trying URL 'https://cloud.r-project.org/src/contrib/emmeans_1.7.1-1.tar.gz'
#
# R[write to console]: Content type 'application/x-gzip'
# R[write to console]:  length 1350443 bytes (1.3 MB)
#
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]:
#
# R[write to console]: downloaded 1.3 MB
#
#
# R[write to console]: trying URL 'https://cloud.r-project.org/src/contrib/ggResidpanel_0.3.0.tar.gz'
#
# R[write to console]: Content type 'application/x-gzip'
# R[write to console]:  length 1702380 bytes (1.6 MB)
#
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]:
#
# R[write to console]: downloaded 1.6 MB
#
#
# R[write to console]: trying URL 'https://cloud.r-project.org/src/contrib/data.table_1.14.2.tar.gz'
#
# R[write to console]: Content type 'application/x-gzip'
# R[write to console]:  length 5301817 bytes (5.1 MB)
#
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]:
#
# R[write to console]: downloaded 5.1 MB
#
#
# R[write to console]: trying URL 'https://cloud.r-project.org/src/contrib/stringr_1.4.0.tar.gz'
#
# R[write to console]: Content type 'application/x-gzip'
# R[write to console]:  length 135777 bytes (132 KB)
#
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]:
#
# R[write to console]: downloaded 132 KB
#
#
# R[write to console]:
#
# R[write to console]:
# R[write to console]: The downloaded source packages are in
# 	‘/tmp/RtmpaSJisQ/downloaded_packages’
# R[write to console]:
# R[write to console]:
# <rpy2.rinterface_lib.sexp.NULLType object at 0x7f471b488730> [RTYPES.NILSXP]

# %%
# %load_ext rpy2.ipython

# %%
# %%R
# library("tidyverse"); theme_set(theme_bw())
# library("lme4")
# library("lmerTest")
# library("emmeans")
# library("ggResidpanel")
# library("data.table")
# library("stringr")
# Out:
# R[write to console]: ── Attaching packages ─────────────────────────────────────── tidyverse 1.3.1 ──
#
# R[write to console]: ✔ ggplot2 3.3.5     ✔ purrr   0.3.4
# ✔ tibble  3.1.6     ✔ dplyr   1.0.7
# ✔ tidyr   1.1.4     ✔ stringr 1.4.0
# ✔ readr   2.1.0     ✔ forcats 0.5.1
#
# R[write to console]: ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
#
# R[write to console]: Loading required package: Matrix
#
# R[write to console]:
# Attaching package: ‘Matrix’
#
#
# R[write to console]: The following objects are masked from ‘package:tidyr’:
#
#     expand, pack, unpack
#
#
# R[write to console]:
# Attaching package: ‘lmerTest’
#
#
# R[write to console]: The following object is masked from ‘package:lme4’:
#
#     lmer
#
#
# R[write to console]: The following object is masked from ‘package:stats’:
#
#     step
#
#
# R[write to console]: data.table 1.14.2 using 1 threads (see ?getDTthreads).  Latest news: r-datatable.com
#
# R[write to console]:
# Attaching package: ‘data.table’
#
#
# R[write to console]: The following objects are masked from ‘package:dplyr’:
#
#     between, first, last
#
#
# R[write to console]: The following object is masked from ‘package:purrr’:
#
#     transpose

# %% [markdown]
# **Data Wrangling**

# %% [markdown]
# Loop through /data/flume directory and merge files into new dataframe. Rename columns to remove some of the poor naming structure and filter out 'NaN' values in response variable column.

# %%
 # %%R
flume <- list.files(path = "./raw/flume", pattern='.csv', full.names = TRUE) %>% 
  map_dfr(read_csv) %>%
  subset(SiteID != 'MAR' & SiteID != 'SPL') %>%
  #setNames(., sub("\\.csv$", "", basename(.))) %>% # to add filename as a column
  #map_dfr(read_csv, .id = "source") %>%
  rename(rainday_in = 'rainday (in)', 
         flowday_in = 'flowday (in)',
         TSS_lbs_ac = 'TSS lbs/ac') %>%
         filter(!is.na(TSS_lbs_ac)) %>%
         mutate(flow_mm = flowday_in * 25.4,
         rain_mm = rainday_in * 25.4,
         runoff_mm = flow_mm / rain_mm,
         TSS_ppm = TSS_lbs_ac * 1.12) %>%
         select(SiteID, Treatment, date, flow_mm, rain_mm, TSS_ppm)
# Out:
# Rows: 2290 Columns: 6
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr (3): SiteID, Treatment, date
# dbl (3): rainday (in), flowday (in), TSS lbs/ac
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
# Rows: 3306 Columns: 6
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr (3): SiteID, Treatment, date
# dbl (3): rainday (in), flowday (in), TSS lbs/ac
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
# Rows: 2547 Columns: 6
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr (3): SiteID, Treatment, date
# dbl (3): rainday (in), flowday (in), TSS lbs/ac
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
# Rows: 2762 Columns: 6
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr (3): SiteID, Treatment, date
# dbl (3): rainday (in), flowday (in), TSS lbs/ac
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.

# %%
# %%R
# # For CSV files
# flumeNA <- list.files(path = "./raw/flume", pattern='.csv', full.names = TRUE) %>%
#   map_dfr(read_csv) %>%
#   subset(SiteID != 'MAR' & SiteID != 'SPL') %>%
#   #setNames(., sub("\\.csv$", "", basename(.))) %>% # to add filename as a column
#   #map_dfr(read_csv, .id = "source") %>%
#   rename(rainday_in = 'rainday (in)',
#          flowday_in = 'flowday (in)',
#          TSS_lbs_ac = 'TSS lbs/ac') %>%
#          mutate(flow_mm = flowday_in * 25.4,
#          rain_mm = rainday_in * 25.4,
#          runoff_mm = flow_mm / rain_mm,
#          TSS_ppm = TSS_lbs_ac * 1.12) %>%
#          select(SiteID, Treatment, date, flow_mm, rain_mm, TSS_ppm)
# Out:
# Rows: 2290 Columns: 6
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr (3): SiteID, Treatment, date
# dbl (3): rainday (in), flowday (in), TSS lbs/ac
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
# Rows: 3306 Columns: 6
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr (3): SiteID, Treatment, date
# dbl (3): rainday (in), flowday (in), TSS lbs/ac
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
# Rows: 2547 Columns: 6
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr (3): SiteID, Treatment, date
# dbl (3): rainday (in), flowday (in), TSS lbs/ac
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
# Rows: 2762 Columns: 6
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr (3): SiteID, Treatment, date
# dbl (3): rainday (in), flowday (in), TSS lbs/ac
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.

# %% [markdown]
# Change 'date' variable into date data type. Extract year from date and create new column with only year value.

# %%
# %%R
# flume$date <- as.Date(flume$date, "%m/%d/%Y")
# flume$Year <- as.numeric(format(flume$date, "%Y"))

# %%
# %%R
# flumeNA$date <- as.Date(flumeNA$date, "%m/%d/%Y")
# flumeNA$Year <- as.numeric(format(flumeNA$date, "%Y"))

# %%
# %%R
# write.csv(flumeNA,"./tidy/flume.csv", row.names=F)

# %% [markdown]
# Subselect from flume annual measurements to create a file with only TSS load observations summed during the observational periods associated with the soil pad dataset.

# %%
# %%R
# times <- read_csv("./raw/site_year_time.csv", )
# Out:
# Rows: 91 Columns: 7
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr (4): SiteID, StartDate, EndDate, station
# dbl (3): Year, Time, Mppt
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.

# %%
# %%R
# add_dates <- function(d) {
#   data.frame(date = seq(as.Date(d$StartDate, format="%m/%d/%Y"),
#                          as.Date(d$EndDate,   format="%m/%d/%Y"),
#                          by = "day"))
# }

# %%
# %%R
# new_times <- times %>%
#   group_by(SiteID, Year, Time) %>%
#   do(add_dates(.)) %>%
#   ungroup()

# %%
# %%R
# index <- c('ARM', 'EIA', 'MCN', 'RHO', 'WHI', 'WOR')
# values <- c("IA0364", "IA1319", "IA1394", "IA5198", "IA4228", "IA0200")
#
# new_times$station <- values[match(new_times$SiteID, index)]
# flumeNA$station <- values[match(flumeNA$SiteID, index)]

# %%
# %%R
# flume_sub <- new_times %>%
#   left_join(flumeNA, by = c("station","date")) %>%
#   filter(!is.na(TSS_ppm)) %>%
#   rename(SiteID = SiteID.x,
#          Year = Year.x) %>%
#   select(SiteID, Year, Treatment, date, flow_mm, rain_mm, TSS_ppm)

# %%
# %%R
# write.csv(flume_sub,"./tidy/flume_sub.csv", row.names=F)

# %% [markdown]
# Loop through /data/weight and merge weight files into new dataframe. Rename columns to remove some of the poor naming structure and filter out 'NaN' values in response variable column.

# %%
# %%R
# all_paths <- list.files(path = "./raw/weight/",
#                         pattern = "*.csv",
#                         full.names=TRUE)

# %%
# %%R
# all_content <- all_paths %>%
# lapply(read.table,
#          header = TRUE,
#          sep = ",",
#          encoding = "UTF-8")

# %%
# %%R
# all_filenames <- all_paths %>%
#   basename() %>%
#   as.list()

# %%
# %%R
# all_lists <- mapply(c, all_content, all_filenames, SIMPLIFY = FALSE)

# %%
# %%R
# all_result <- rbindlist(all_lists, fill = T) %>%
# rename(PanID = Pan.ID,
#        Cup_g = Cup..g.,
#        Cup_soil = Cup...soil,
#        filename = V1)

# %% [markdown]
# Modify columns in weight all_results dataframe.

# %%
# %%R
# all_raw <- all_result %>%
# mutate(filename = gsub("\\.[^.]*$", "", filename))

# %%
# %%R
# split_into_multiple <- function(column, pattern = ", ", into_prefix){
#   cols <- str_split_fixed(column, pattern, n = Inf)
#   # Sub out the ""'s returned by filling the matrix to the right, with NAs which are useful
#   cols[which(cols == "")] <- NA
#   cols <- as.tibble(cols)
#   # name the 'cols' tibble as 'into_prefix_1', 'into_prefix_2', ..., 'into_prefix_m'
#   # where m = # columns of 'cols'
#   m <- dim(cols)[2]
#
#   names(cols) <- paste(into_prefix, 1:m, sep = "_")
#   return(cols)
# }

# %%
# %%R
# weight_raw <- all_raw %>%
#   bind_cols(split_into_multiple(.$filename, "_", "type")) %>%
#   rename(Year = type_1,
#          SiteID = type_2,
#          Time = type_3) %>%
#   mutate(weight = Cup_soil - Cup_g,
#          trt_code = case_when(endsWith(Treatment, 'l') ~ "C",
#                               endsWith(Treatment, 's') ~ "T"),
#          PanID = str_pad(PanID, 2, pad="0"),
#          PadID = paste(SiteID, PanID, trt_code, sep=""),
#          Year = as.double(Year),
#          Time = as.double(Time)) %>%
#   filter(!is.na(weight)) %>%
#   # selecting those that start with 'type_' will remove the original 'type' column
#   select(Year, SiteID, Treatment, Position, Time, PadID, weight)

# %% [markdown]
# Merge weight measurements observed on the pads with experiment characteristics organized by site, year and time collected in order to add number of days within an observational period and amount of precipitation.

# %%
# %%R
# site_year_time <- times %>%
# mutate(EndDate = as.Date(EndDate,   format="%m/%d/%Y"),
#        StartDate = as.Date(StartDate, format="%m/%d/%Y"),
#        Days = as.numeric(EndDate - StartDate))

# %%
# %%R
# weight <- weight_raw %>%
# left_join(site_year_time, by = c("SiteID","Year","Time")) %>%
# mutate(wpd = weight/Days) %>%
# select(Year, SiteID, Treatment, Position, Time, PadID, weight, Mppt, Days, wpd)

# %%
# %%R
# write.csv(weight,"./tidy/weight.csv", row.names=F)

# %% [markdown]
# **Exploratory Graphics**

# %% [markdown]
# Organize the flume data to look at counts and distribution of datapoints across years, sites and treatments.

# %%
# %%R
# flume_counts <- flume %>%
#          group_by(SiteID, Treatment, Year) %>%
#          summarize(n = n(), .groups = "drop")

# %%
# %%R
# g = ggplot(flume_counts,
#        aes(x = Treatment, y = SiteID, fill = n)) +
#   geom_tile() +
#   geom_text(aes(label = n), color = "white") +
#   facet_grid( ~ Year) +
#   scale_fill_gradient(low = "blue", high = "black") +
#   theme(axis.text.x = element_text(angle = 45, hjust = 1))
#
# g

# %%
# %%R
# flumeNA_counts <- flumeNA %>%
#          group_by(SiteID, Treatment, Year) %>%
#          summarize(n = n(), .groups = "drop")

# %%
# %%R
# gNA = ggplot(flumeNA_counts,
#        aes(x = Treatment, y = SiteID, fill = n)) +
#   geom_tile() +
#   geom_text(aes(label = n), color = "white") +
#   facet_grid( ~ Year) +
#   scale_fill_gradient(low = "blue", high = "black") +
#   theme(axis.text.x = element_text(angle = 45, hjust = 1))
#
# gNA

# %%
# %%R
# flumesub_counts <- flume_sub %>%
#          group_by(SiteID, Treatment, Year) %>%
#          summarize(n = n(), .groups = "drop")

# %%
# %%R
# gsub = ggplot(flumesub_counts,
#        aes(x = Treatment, y = SiteID, fill = n)) +
#   geom_tile() +
#   geom_text(aes(label = n), color = "white") +
#   facet_grid( ~ Year) +
#   scale_fill_gradient(low = "blue", high = "black") +
#   theme(axis.text.x = element_text(angle = 45, hjust = 1))
#
# gsub

# %%
# %%R
# weight_counts <- weight %>%
#          group_by(SiteID, Treatment, Year) %>%
#          summarize(n = n(), .groups = "drop")

# %%
# %%R
# gw = ggplot(weight_counts,
#        aes(x = Treatment, y = SiteID, fill = n)) +
#   geom_tile() +
#   geom_text(aes(label = n), color = "white") +
#   facet_grid( ~ Year) +
#   scale_fill_gradient(low = "blue", high = "black") +
#   theme(axis.text.x = element_text(angle = 45, hjust = 1))
#
# gw

# %%
# %%R
# flume_sum <- flume %>%
#   group_by(Year, SiteID, Treatment) %>%
#   summarize(sum_flow_mm = sum(flow_mm, na.rm = TRUE),
#             sum_TSS_ppm = sum(TSS_ppm, na.rm = TRUE),
#             log_TSS = log(sum_TSS_ppm),
#             n            = n(),
#             .groups = "drop")

# %%
# %%R
# h <- ggplot(flume_sum %>%
#               group_by(SiteID, Year, Treatment),
#             aes(x = Treatment, y = sum_TSS_ppm)) +
#   geom_point() +
#   facet_grid(SiteID ~ Year, scales = "free_y") +
#   theme(axis.text.x = element_text(angle = 90, hjust = 1, vjust = 0.5))
#
# h

# %%
# %%R
# k <- ggplot(flume_sum %>%
#             group_by(Treatment),
#             aes(x = Treatment, y = sum_TSS_ppm)) +
#   geom_bar(stat='identity') +
#   theme(axis.text.x = element_text(angle = 90, hjust = 1, vjust = 0.5))
#
# k

# %%
# %%R
# flumeNA_sum <- flumeNA %>%
#   group_by(Year, SiteID, Treatment) %>%
#   summarize(sum_flow_mm = sum(flow_mm, na.rm = TRUE),
#             sum_TSS_ppm = sum(TSS_ppm, na.rm = TRUE),
#             log_TSS = log(sum_TSS_ppm),
#             n = n(),
#             .groups = "drop")

# %%
# %%R
# hNA <- ggplot(flumeNA_sum %>%
#               group_by(SiteID, Year, Treatment),
#             aes(x = Treatment, y = sum_TSS_ppm)) +
#   geom_point() +
#   facet_grid(SiteID ~ Year, scales = "free_y") +
#   theme(axis.text.x = element_text(angle = 90, hjust = 1, vjust = 0.5))
#
# hNA

# %%
# %%R
# kNA <- ggplot(flumeNA_sum %>%
#             group_by(Treatment),
#             aes(x = Treatment, y = sum_TSS_ppm)) +
#   geom_bar(stat='identity') +
#   theme(axis.text.x = element_text(angle = 90, hjust = 1, vjust = 0.5))
#
# kNA

# %%
# %%R
# flumesub_sum <- flume_sub %>%
#   group_by(Year, SiteID, Treatment) %>%
#   summarize(sum_flow_mm = sum(flow_mm, na.rm = TRUE),
#             sum_TSS_ppm = sum(TSS_ppm, na.rm = TRUE),
#             log_TSS = log(sum_TSS_ppm),
#             n = n(),
#             .groups = "drop")

# %%
# %%R
# hsub <- ggplot(flumesub_sum %>%
#               group_by(SiteID, Year, Treatment),
#             aes(x = Treatment, y = sum_TSS_ppm)) +
#   geom_point() +
#   facet_grid(SiteID ~ Year, scales = "free_y") +
#   theme(axis.text.x = element_text(angle = 90, hjust = 1, vjust = 0.5))
#
# hsub

# %%
# %%R
# ksub <- ggplot(flumesub_sum %>%
#             group_by(Treatment),
#             aes(x = Treatment, y = sum_TSS_ppm)) +
#   geom_bar(stat='identity') +
#   theme(axis.text.x = element_text(angle = 90, hjust = 1, vjust = 0.5))
#
# ksub

# %%
# %%R
# weight_sum <- weight %>%
#   group_by(Year, SiteID, Treatment) %>%
#   summarize(sum_wpd = sum(wpd, na.rm=TRUE),
#             n = n(),
#             .groups = "drop")

# %%
# %%R
# hw <- ggplot(weight_sum %>%
#               group_by(SiteID, Year, Treatment),
#             aes(x = Treatment, y = sum_wpd)) +
#   geom_point() +
#   facet_grid(SiteID ~ Year, scales = "free_y") +
#   theme(axis.text.x = element_text(angle = 90, hjust = 1, vjust = 0.5))
#
# hw

# %%
# %%R
# kw <- ggplot(weight_sum %>%
#             group_by(Treatment),
#             aes(x = Treatment, y = sum_wpd)) +
#   geom_bar(stat='identity') +
#   theme(axis.text.x = element_text(angle = 90, hjust = 1, vjust = 0.5))
#
# kw

# %% [markdown]
# **Data Analysis Begins**

# %%
# %%R
# m1_flume <- lmerTest::lmer(TSS_ppm ~
#            (1 | SiteID) +
#            Treatment +
#            (1 | SiteID:Treatment) +
#            Year * Treatment,
#            data = flume)
# Out:
# R[write to console]: boundary (singular) fit: see ?isSingular

# %%
# %%R
# resid_panel(m1_flume, plots = c("resid","index","yvp","qq"),
#             smoother = TRUE, qqbands = TRUE)
# Out:
# R[write to console]: `geom_smooth()` using formula 'y ~ x'
#
# R[write to console]: `geom_smooth()` using formula 'y ~ x'

# %%
# %%R
# resid_xpanel(m1_flume)

# %%
# %%R
# m1_step <- step(m1_flume, reduce.random = FALSE)
# Out:
# R[write to console]: boundary (singular) fit: see ?isSingular
#
# R[write to console]: boundary (singular) fit: see ?isSingular

# %% [markdown]
# Data needs to be log-transformed due data being skewed and not meeting the assumptions of normality and constant variance.

# %%
# %%R
# m2_flume <- lmerTest::lmer(log(TSS_ppm) ~
#            (1 | SiteID) +
#            Treatment +
#            (1 | SiteID:Treatment) +
#            factor(Year) * Treatment,
#            data = flume)

# %%
# %%R
# m2_flume_step <- step(m2_flume, reduce.random = FALSE)
# m2_flume_step
# Out:
# Backward reduced random-effect table:
#
#                        Eliminated npar  logLik    AIC     LRT Df Pr(>Chisq)
# <none>                              11 -965.68 1953.4
# (1 | SiteID)                    0   10 -966.06 1952.1 0.76711  1     0.3811
# (1 | SiteID:Treatment)          0   10 -966.54 1953.1 1.71073  1     0.1909
#
# Backward reduced fixed-effect table:
# Degrees of freedom method: Satterthwaite
#
#                        Eliminated Sum Sq Mean Sq NumDF  DenDF F value   Pr(>F)
# Treatment:factor(Year)          0 98.986  32.995     3 252.72  4.3481 0.005224
#
# Treatment:factor(Year) **
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Model found:
# log(TSS_ppm) ~ (1 | SiteID) + Treatment + (1 | SiteID:Treatment) + factor(Year) * Treatment

# %%
# %%R
# m2_flume_step <- get_model(m2_flume_step)
# summary(m2_flume_step)
# Out:
# Linear mixed model fit by REML. t-tests use Satterthwaite's method [
# lmerModLmerTest]
# Formula: log(TSS_ppm) ~ (1 | SiteID) + Treatment + (1 | SiteID:Treatment) +
#     factor(Year) * Treatment
#    Data: flume
#
# REML criterion at convergence: 1931.4
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -4.2444 -0.5067  0.1226  0.7267  2.0627
#
# Random effects:
#  Groups           Name        Variance Std.Dev.
#  SiteID:Treatment (Intercept) 0.4815   0.6939
#  SiteID           (Intercept) 0.5510   0.7423
#  Residual                     7.5884   2.7547
# Number of obs: 396, groups:  SiteID:Treatment, 12; SiteID, 6
#
# Fixed effects:
#                                   Estimate Std. Error        df t value
# (Intercept)                       -0.08829    0.61904  19.83735  -0.143
# Treatmentstrips                   -2.08790    0.87672  18.92746  -2.381
# factor(Year)2017                   1.02961    0.69641 382.56923   1.478
# factor(Year)2018                  -0.94689    0.55015 387.47373  -1.721
# factor(Year)2019                   0.83274    0.61541 383.14994   1.353
# Treatmentstrips:factor(Year)2017  -0.35594    1.21061 237.04291  -0.294
# Treatmentstrips:factor(Year)2018   2.44395    0.88756 224.26298   2.754
# Treatmentstrips:factor(Year)2019   1.47597    0.99714 139.16662   1.480
#                                  Pr(>|t|)
# (Intercept)                       0.88802
# Treatmentstrips                   0.02790 *
# factor(Year)2017                  0.14011
# factor(Year)2018                  0.08602 .
# factor(Year)2019                  0.17681
# Treatmentstrips:factor(Year)2017  0.76900
# Treatmentstrips:factor(Year)2018  0.00638 **
# Treatmentstrips:factor(Year)2019  0.14108
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Correlation of Fixed Effects:
#             (Intr) Trtmnt f(Y)2017 f(Y)2018 f(Y)2019 T:(Y)2017 T:(Y)2018
# Trtmntstrps -0.529
# fctr(Y)2017 -0.478  0.327
# fctr(Y)2018 -0.625  0.435  0.554
# fctr(Y)2019 -0.553  0.377  0.545    0.644
# Trt:(Y)2017  0.269 -0.590 -0.560   -0.313   -0.297
# Trt:(Y)2018  0.376 -0.766 -0.332   -0.607   -0.383    0.582
# Trt:(Y)2019  0.329 -0.728 -0.320   -0.384   -0.596    0.584     0.731

# %%
# %%R
# resid_panel(m2_flume, plots = c("resid","index","yvp","qq"),
#             smoother = TRUE, qqbands = TRUE)

# %%
# %%R
# resid_xpanel(m2_flume)

# %%
# %%R
# m1_sub <- lmerTest::lmer(TSS_ppm ~
#            (1 | SiteID) +
#            Treatment +
#            (1 | SiteID:Treatment) +
#            factor(Year) * Treatment,
#            data = flume_sub)

# %%
# %%R
# resid_panel(m1_sub, plots = c("resid","index","yvp","qq"),
#             smoother = TRUE, qqbands = TRUE)

# %%
# %%R
# resid_xpanel(m1_sub)

# %%
# %%R
# m2_sub <- lmerTest::lmer(log(TSS_ppm) ~
#            (1 | SiteID) +
#            Treatment +
#            (1 | SiteID:Treatment) +
#            factor(Year) * Treatment,
#            data = flume_sub)
# Out:
# R[write to console]: boundary (singular) fit: see ?isSingular

# %%
# %%R
# resid_panel(m2_sub, plots = c("resid","index","yvp","qq"),
#             smoother = TRUE, qqbands = TRUE)
# Out:
# R[write to console]: `geom_smooth()` using formula 'y ~ x'
#
# R[write to console]: `geom_smooth()` using formula 'y ~ x'

# %%
# %%R
# resid_xpanel(m2_sub)

# %%
# %%R
# m2_sub_step <- step(m2_sub, reduce.random = FALSE)
# m2_sub_step
# Out:
# R[write to console]: boundary (singular) fit: see ?isSingular
# Backward reduced random-effect table:
#
#                        Eliminated npar  logLik    AIC    LRT Df Pr(>Chisq)
# <none>                              11 -388.02 798.04
# (1 | SiteID)                    0   10 -388.02 796.04 0.0000  1    1.00000
# (1 | SiteID:Treatment)          0   10 -391.19 802.38 6.3399  1    0.01181 *
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Backward reduced fixed-effect table:
# Degrees of freedom method: Satterthwaite
#
#                        Eliminated  Sum Sq Mean Sq NumDF   DenDF F value
# Treatment:factor(Year)          1  56.110  18.703     3 145.593  2.1529
# Treatment                       2   0.999   0.999     1   8.402  0.1124
# factor(Year)                    0 162.032  54.011     3 143.272  6.0702
#                           Pr(>F)
# Treatment:factor(Year) 0.0961444 .
# Treatment              0.7456058
# factor(Year)           0.0006423 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Model found:
# log(TSS_ppm) ~ (1 | SiteID) + (1 | SiteID:Treatment) + factor(Year)

# %%
# %%R
# summary(m2_sub)
# Out:
# Linear mixed model fit by REML. t-tests use Satterthwaite's method [
# lmerModLmerTest]
# Formula: log(TSS_ppm) ~ (1 | SiteID) + Treatment + (1 | SiteID:Treatment) +
#     factor(Year) * Treatment
#    Data: flume_sub
#
# REML criterion at convergence: 776
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -2.7833 -0.3850  0.1411  0.5879  2.5745
#
# Random effects:
#  Groups           Name        Variance Std.Dev.
#  SiteID:Treatment (Intercept) 5.469    2.339
#  SiteID           (Intercept) 0.000    0.000
#  Residual                     8.688    2.947
# Number of obs: 155, groups:  SiteID:Treatment, 12; SiteID, 6
#
# Fixed effects:
#                                   Estimate Std. Error        df t value
# (Intercept)                       -0.06627    1.48350  31.43588  -0.045
# Treatmentstrips                   -1.98596    2.10215  30.60233  -0.945
# factor(Year)2017                   1.02331    1.30955 138.58369   0.781
# factor(Year)2018                  -1.64874    1.27847 144.95388  -1.290
# factor(Year)2019                   1.93240    1.30746 141.60832   1.478
# Treatmentstrips:factor(Year)2017  -1.30316    2.09678 142.03032  -0.622
# Treatmentstrips:factor(Year)2018   2.84413    1.80032 145.75470   1.580
# Treatmentstrips:factor(Year)2019   0.99853    1.93132 146.29973   0.517
#                                  Pr(>|t|)
# (Intercept)                         0.965
# Treatmentstrips                     0.352
# factor(Year)2017                    0.436
# factor(Year)2018                    0.199
# factor(Year)2019                    0.142
# Treatmentstrips:factor(Year)2017    0.535
# Treatmentstrips:factor(Year)2018    0.116
# Treatmentstrips:factor(Year)2019    0.606
#
# Correlation of Fixed Effects:
#             (Intr) Trtmnt f(Y)2017 f(Y)2018 f(Y)2019 T:(Y)2017 T:(Y)2018
# Trtmntstrps -0.706
# fctr(Y)2017 -0.534  0.377
# fctr(Y)2018 -0.698  0.493  0.599
# fctr(Y)2019 -0.644  0.455  0.636    0.772
# Trt:(Y)2017  0.334 -0.519 -0.625   -0.374   -0.397
# Trt:(Y)2018  0.496 -0.684 -0.426   -0.710   -0.548    0.584
# Trt:(Y)2019  0.436 -0.652 -0.430   -0.523   -0.677    0.606     0.777
# optimizer (nloptwrap) convergence code: 0 (OK)
# boundary (singular) fit: see ?isSingular

# %%
# %%R
# m3_sub <- lmerTest::lmer(sqrt(TSS_ppm) ~
#            (1 | SiteID) +
#            Treatment +
#            (1 | SiteID:Treatment) +
#            factor(Year) * Treatment,
#            data = flume_sub)

# %%
# %%R
# resid_panel(m3_sub, plots = c("resid","index","yvp","qq"),
#             smoother = TRUE, qqbands = TRUE)

# %%
# %%R
# resid_xpanel(m3_sub)

# %%
# %%R
# m3_sub_step <- step(m3_sub, reduce.random = FALSE)
# m3_sub_step

# %%
# %%R
# m1_pad <-
#   lmerTest::lmer(wpd ~
#            (1 | SiteID) +
#            Treatment +
#            (1 | SiteID:Treatment) +
#            Position +
#            Treatment * Position +
#            (1 | SiteID:Treatment:Position) + # removed due to singularity
#            factor(Year) * Treatment +
#            (1|SiteID:Treatment:Position:Time),
#          data = weight)

# %%
# %%R
# resid_panel(m1_pad, plots = c("resid","index","yvp","qq"),
#             smoother = TRUE, qqbands = TRUE)

# %%
# %%R
# resid_xpanel(m1_pad)

# %%
# %%R
# m2_pad <-
#   lmerTest::lmer(log(wpd+0.002) ~
#            (1 | SiteID) +
#            Treatment +
#            (1 | SiteID:Treatment) +
#            Position +
#            Treatment * Position +
#            (1 | SiteID:Treatment:Position) + # removed due to singularity
#            factor(Year) * Treatment +
#            (1|SiteID:Treatment:Position:Time),
#          data = weight)

# %%
# %%R
# resid_panel(m2_pad, plots = c("resid","index","yvp","qq"),
#             smoother = TRUE, qqbands = TRUE)

# %%
# %%R
# resid_xpanel(m2_pad)

# %%
# %%R
# m2_pad_step <- step(m2_pad, reduce.random = FALSE)
# m2_pad_step

# %%
# %%R
# m2_pad_step <- get_model(m2_pad_step)
# summary(m2_pad_step)
# Out:
# Linear mixed model fit by REML. t-tests use Satterthwaite's method [
# lmerModLmerTest]
# Formula:
# log(wpd + 0.002) ~ (1 | SiteID) + Treatment + (1 | SiteID:Treatment) +
#     (1 | SiteID:Treatment:Position) + factor(Year) + (1 | SiteID:Treatment:Position:Time) +
#     Treatment:factor(Year)
#    Data: weight
#
# REML criterion at convergence: 11259.9
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -4.8925 -0.6295 -0.0796  0.5718  4.6384
#
# Random effects:
#  Groups                         Name        Variance Std.Dev.
#  SiteID:Treatment:Position:Time (Intercept) 0.12912  0.3593
#  SiteID:Treatment:Position      (Intercept) 0.02012  0.1419
#  SiteID:Treatment               (Intercept) 0.04026  0.2006
#  SiteID                         (Intercept) 0.75378  0.8682
#  Residual                                   1.44095  1.2004
# Number of obs: 3453, groups:
# SiteID:Treatment:Position:Time, 108; SiteID:Treatment:Position, 36; SiteID:Treatment, 12; SiteID, 6
#
# Fixed effects:
#                                    Estimate Std. Error         df t value
# (Intercept)                        -1.69550    0.37794    5.91844  -4.486
# TreatmentStrips                    -0.12903    0.18546   11.89185  -0.696
# factor(Year)2017                    0.53712    0.09836 3415.15666   5.461
# factor(Year)2018                    0.77634    0.09847 3415.85931   7.884
# factor(Year)2019                    1.31063    0.10413 3393.64486  12.587
# TreatmentStrips:factor(Year)2017   -0.28561    0.13905 3400.81647  -2.054
# TreatmentStrips:factor(Year)2018    0.13348    0.13907 3401.90398   0.960
# TreatmentStrips:factor(Year)2019   -0.10098    0.14704 3298.62971  -0.687
#                                  Pr(>|t|)
# (Intercept)                       0.00431 **
# TreatmentStrips                   0.49997
# factor(Year)2017                 5.09e-08 ***
# factor(Year)2018                 4.22e-15 ***
# factor(Year)2019                  < 2e-16 ***
# TreatmentStrips:factor(Year)2017  0.04004 *
# TreatmentStrips:factor(Year)2018  0.33721
# TreatmentStrips:factor(Year)2019  0.49228
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Correlation of Fixed Effects:
#             (Intr) TrtmnS f(Y)2017 f(Y)2018 f(Y)2019 TS:(Y)2017 TS:(Y)2018
# TrtmntStrps -0.245
# fctr(Y)2017 -0.188  0.382
# fctr(Y)2018 -0.187  0.381  0.720
# fctr(Y)2019 -0.179  0.364  0.688    0.686
# TrS:(Y)2017  0.133 -0.541 -0.706   -0.508   -0.485
# TrS:(Y)2018  0.132 -0.541 -0.509   -0.707   -0.484    0.721
# TrS:(Y)2019  0.126 -0.516 -0.486   -0.484   -0.705    0.688      0.687

# %% [markdown]
# Contrasts

# %%
# %%R
# treat_year_flume = emmeans(m2, pairwise ~ Treatment|Year,
#                     type = "response",
#                     lmer.df = "asymptotic", lmerTest.limit = 5822)
#
#
# confint(treat_year_flume)$contrasts
# Out:
# Year = 2016:
#  contrast         ratio     SE  df asymp.LCL asymp.UCL
#  control / strips  8.07  7.073 Inf     1.447     44.98
#
# Year = 2017:
#  contrast         ratio     SE  df asymp.LCL asymp.UCL
#  control / strips 11.52 11.406 Inf     1.653     80.23
#
# Year = 2018:
#  contrast         ratio     SE  df asymp.LCL asymp.UCL
#  control / strips  0.70  0.423 Inf     0.214      2.29
#
# Year = 2019:
#  contrast         ratio     SE  df asymp.LCL asymp.UCL
#  control / strips  1.84  1.292 Inf     0.467      7.28
#
# Degrees-of-freedom method: asymptotic
# Confidence level used: 0.95
# Intervals are back-transformed from the log scale

# %%
# %%R
# treat_year = emmeans(m2_sub, pairwise ~ Treatment|Year,
#                     type = "response",
#                     lmer.df = "asymptotic", lmerTest.limit = 5822)
#
#
# confint(treat_year)$contrasts
# Out:
# Year = 2016:
#  contrast          ratio     SE  df asymp.LCL asymp.UCL
#  control / strips  7.286 15.316 Inf    0.1183     448.6
#
# Year = 2017:
#  contrast          ratio     SE  df asymp.LCL asymp.UCL
#  control / strips 26.819 55.204 Inf    0.4746    1515.5
#
# Year = 2018:
#  contrast          ratio     SE  df asymp.LCL asymp.UCL
#  control / strips  0.424  0.668 Inf    0.0193       9.3
#
# Year = 2019:
#  contrast          ratio     SE  df asymp.LCL asymp.UCL
#  control / strips  2.684  4.536 Inf    0.0978      73.7
#
# Degrees-of-freedom method: asymptotic
# Confidence level used: 0.95
# Intervals are back-transformed from the log scale

# %%
# %%R
# year = emmeans(m2, ~ Year,
#                   type = "response",
#                   lmer.df = "satterthwaite", lmerTest.limit = 5822)
#
# confint(year)
# Out:
# R[write to console]: NOTE: Results may be misleading due to involvement in interactions
#  Year response    SE    df lower.CL upper.CL
#  2016    0.322 0.173 13.36    0.101     1.02
#  2017    0.755 0.442 19.53    0.222     2.57
#  2018    0.424 0.182  5.93    0.148     1.22
#  2019    1.550 0.722  8.05    0.531     4.53
#
# Results are averaged over the levels of: Treatment
# Degrees-of-freedom method: satterthwaite
# Confidence level used: 0.95
# Intervals are back-transformed from the log scale

# %%
# %%R
# treatment = emmeans(m2_sub, pairwise ~ Treatment,
#                   type = "response",
#                   lmer.df = "satterthwaite", lmerTest.limit = 5822)
#
# confint(treatment)
# Out:
# R[write to console]: NOTE: Results may be misleading due to involvement in interactions
# $emmeans
#  Treatment response    SE   df lower.CL upper.CL
#  control      1.298 1.382 9.12   0.1172    14.37
#  strips       0.336 0.361 9.43   0.0301     3.75
#
# Results are averaged over the levels of: Year
# Degrees-of-freedom method: satterthwaite
# Confidence level used: 0.95
# Intervals are back-transformed from the log scale
#
# $contrasts
#  contrast         ratio   SE   df lower.CL upper.CL
#  control / strips  3.86 5.84 9.27    0.128      116
#
# Results are averaged over the levels of: Year
# Degrees-of-freedom method: satterthwaite
# Confidence level used: 0.95
# Intervals are back-transformed from the log scale

# %% [markdown]
# **Data Visualization**

# %%
# %%R
# treatment <- as.data.frame(treatment)

# %%
# %%R
# trt <-treatment %>%
#   filter(contrast != "control - strips")

# %%
# %%R
# trt_plot <- trt %>%
#   ggplot(aes(x=Treatment, y=response, fill=Treatment))+
#   theme_classic() +
#   geom_bar(width = 0.5, position = position_dodge(), stat="summary") +
#   geom_errorbar(aes(ymin = (response-SE), ymax = (response+SE)),
#             width = 0.2,
#             linetype = "solid",
#             position = position_dodge(width = 0.5),
#             color="black", size=0.7) +
#   #scale_fill_manual(values=c('#176D9C','#C38820'), labels=c("Control","Prairie Strips")) +
#   scale_fill_manual(values = c("control" = "#176D9C",
#                                "strips" = "#C38820")) +
#   ggtitle("Treatment vs. Control: \nMean Total Suspended Solids (TSS) Load \n during Field Season ") +
#   xlab("Treatment") +
#   ylab("TSS Load (ppm)") +
#   theme(plot.title = element_text(size=16, face="bold", hjust=0.5),
#         axis.title.x = element_text(size=14, face="bold"),
#         axis.title.y = element_text(size=14, face="bold"),
#         axis.text.x = element_text(size=12),
#         axis.text.y = element_text(size=12)) +
#   scale_x_discrete(labels= c("Control", "Prairie Strip"))
#
#   trt_plot
# Out:
# R[write to console]: No summary function supplied, defaulting to `mean_se()`

# %%
# %%R
# treat_year <- as.data.frame(treat_year)

# %%
# %%R
# j <-treat_year %>%
#   filter(contrast == "control - strips")

# %%
# %%R
# k <-treat_year %>%
#   filter(contrast != "control - strips")

# %%
# %%R
# treat_ratio <- j %>%
#   ggplot(aes(x=Year, y=response)) +
#   theme_classic() +
#   geom_bar(width = 0.5, position = position_dodge(), stat="summary", fill="#FF6666") +
#   geom_errorbar(aes(ymin = (response-SE), ymax = (response+SE)),
#             width = 0.2,
#             linetype = "solid",
#             position = position_dodge(width = 0.5),
#             color="black", size=0.7) +
#   ggtitle("Treatment vs. Control: \nTotal Suspended Solids (TSS) Load") +
#   xlab("Year") +
#   ylab("Ratio of Watershed TSS Load (-/+ prairie)") +
#   theme(plot.title = element_text(size=16, face="bold", hjust=0.5),
#         axis.title.x = element_text(size=14, face="bold"),
#         axis.title.y = element_text(size=14, face="bold"),
#         axis.text.x = element_text(size=12),
#         axis.text.y = element_text(size=12))
#
# treat_ratio
# Out:
# R[write to console]: No summary function supplied, defaulting to `mean_se()`

# %%
# %%R
# treat_plot <- k %>%
#   ggplot(aes(x=Year, y=response, fill=Treatment)) +
#   theme_classic() +
#   theme(legend.position = 'top', legend.title=element_blank()) +
#   geom_bar(width = 0.5, position = position_dodge(), stat="summary") +
#   #geom_errorbar(aes(ymin = (response-SE), ymax = (response+SE)),
#   #          width = 0.2,
#   #          linetype = "solid",
#   #          position = position_dodge(width = 0.5),
#   #          color="black", size=0.7) +
#   scale_fill_manual(values=c('#176D9C','#C38820'), labels=c("Control","Prairie Strips")) +
#   ggtitle("Treatment vs. Control: \nMean Total Suspended Solids (TSS) Load \n during Field Season") +
#   xlab("Year") +
#   ylab("Mean TSS Load (ppm)") +
#   theme(plot.title = element_text(size=16, face="bold", hjust=0.5),
#         axis.title.x = element_text(size=14, face="bold"),
#         axis.title.y = element_text(size=14, face="bold"),
#         axis.text.x = element_text(size=12),
#         axis.text.y = element_text(size=12))
#   #scale_x_discrete(labels= c("Below Strip \n Foot Slope", "Between Strip \n Mid-Slope", "Above Strip \n Top Slope"))
#
# treat_plot
# Out:
# R[write to console]: No summary function supplied, defaulting to `mean_se()`

# %%
plot the emmeans by treatment and year
pull in covariates and do a stack analysis...random forest? additional predictor variables?
